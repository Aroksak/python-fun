# %%
import pandas as pd
import numpy as np
import glob
from PIL import Image
from tqdm import tqdm
import imageio
import keras
from tensorflow.image import rot90, crop_to_bounding_box
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
path = './data/zoo/galaxy-zoo-the-galaxy-challenge/'

# %%
if False:

    for imagename in tqdm(glob.glob(path+'images_training_rev1/*.jpg')):
        im = Image.open(imagename)
        w, h = im.size
        im = im.crop((108, 108, w-109, h-109))
        im = im.resize((69,69))
        im.save(path+'train/'+imagename.split('/')[-1].split('.')[0]+'.png')

    for imagename in tqdm(glob.glob(path+'images_test_rev1/*.jpg')):
        im = Image.open(imagename)
        w, h = im.size
        im = im.crop((108, 108, w-109, h-109))
        im = im.resize((69,69))
        im.save(path+'test/'+imagename.split('/')[-1].split('.')[0]+'.png')
# Out:
# 100%|██████████| 61578/61578 [27:29<00:00, 37.19it/s]

# %%
def crop_rot(image, x0, y0, rot=0):
    return crop_to_bounding_box(rot90(image, k=rot), x0, y0, 45, 45)


main_input = keras.Input(shape=(69,69,3))
top_left = [keras.layers.core.Lambda(lambda x: crop_rot(x, 0, 0, k), 
                                    output_shape=(45,45,3))(main_input) for k in range(4)]
top_right = [keras.layers.core.Lambda(lambda x: crop_rot(x, 0, 24, k), 
                                    output_shape=(45,45,3))(main_input) for k in range(4)]
bottom_left = [keras.layers.core.Lambda(lambda x: crop_rot(x, 24, 0, k), 
                                    output_shape=(45,45,3))(main_input) for k in range(4)]
bottom_right = [keras.layers.core.Lambda(lambda x: crop_rot(x, 24, 24, k), 
                                    output_shape=(45,45,3))(main_input) for k in range(4)]

conv_32 = keras.layers.Conv2D(32, (6,6), activation='relu', input_shape=(45,45,3))
maxpool_20 = keras.layers.MaxPooling2D(pool_size=2)
conv_64 = keras.layers.Conv2D(64, (5,5), activation='relu')
maxpool_8 = keras.layers.MaxPooling2D(pool_size=2)
conv_128_0 = keras.layers.Conv2D(128, (3,3), activation='relu')
conv_128_1 = keras.layers.Conv2D(128, (3,3), activation='relu')
maxpool_2 = keras.layers.MaxPooling2D(pool_size=2)

convolutions_output = []

for output in [*top_left, *top_right, *bottom_left, *bottom_right]:
    x = conv_32(output)
    x = maxpool_20(x)
    x = conv_64(x)
    x = maxpool_8(x)
    x = conv_128_0(x)
    x = conv_128_1(x)
    x = maxpool_2(x)
    x = keras.layers.Flatten()(x)
    convolutions_output.append(x)
    
merge = keras.layers.concatenate(convolutions_output)
dropout_0 = keras.layers.Dropout(0.5)(merge)
dense_0 = keras.layers.Dense(2048, activation='relu')(dropout_0)
dropout_1 = keras.layers.Dropout(0.5)(dense_0)
dense_1 = keras.layers.Dense(2048, activation='relu')(dropout_1)
dropout_2 = keras.layers.Dropout(0.5)(dense_1)
main_output = keras.layers.Dense(37, activation='relu')(dropout_2)

big_model = keras.Model(inputs=[main_input], outputs=[main_output])
big_model.compile(optimizer='adam', loss='mse')
keras.utils.plot_model(big_model, to_file='model.png', show_shapes=True, show_layer_names=False)
big_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 69, 69, 3)    0
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 45, 45, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 40, 40, 32)   3488        lambda_81[0][0]
#                                                                  lambda_82[0][0]
#                                                                  lambda_83[0][0]
#                                                                  lambda_84[0][0]
#                                                                  lambda_85[0][0]
#                                                                  lambda_86[0][0]
#                                                                  lambda_87[0][0]
#                                                                  lambda_88[0][0]
#                                                                  lambda_89[0][0]
#                                                                  lambda_90[0][0]
#                                                                  lambda_91[0][0]
#                                                                  lambda_92[0][0]
#                                                                  lambda_93[0][0]
#                                                                  lambda_94[0][0]
#                                                                  lambda_95[0][0]
#                                                                  lambda_96[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 20, 20, 32)   0           conv2d_21[0][0]
#                                                                  conv2d_21[1][0]
#                                                                  conv2d_21[2][0]
#                                                                  conv2d_21[3][0]
#                                                                  conv2d_21[4][0]
#                                                                  conv2d_21[5][0]
#                                                                  conv2d_21[6][0]
#                                                                  conv2d_21[7][0]
#                                                                  conv2d_21[8][0]
#                                                                  conv2d_21[9][0]
#                                                                  conv2d_21[10][0]
#                                                                  conv2d_21[11][0]
#                                                                  conv2d_21[12][0]
#                                                                  conv2d_21[13][0]
#                                                                  conv2d_21[14][0]
#                                                                  conv2d_21[15][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   51264       max_pooling2d_16[0][0]
#                                                                  max_pooling2d_16[1][0]
#                                                                  max_pooling2d_16[2][0]
#                                                                  max_pooling2d_16[3][0]
#                                                                  max_pooling2d_16[4][0]
#                                                                  max_pooling2d_16[5][0]
#                                                                  max_pooling2d_16[6][0]
#                                                                  max_pooling2d_16[7][0]
#                                                                  max_pooling2d_16[8][0]
#                                                                  max_pooling2d_16[9][0]
#                                                                  max_pooling2d_16[10][0]
#                                                                  max_pooling2d_16[11][0]
#                                                                  max_pooling2d_16[12][0]
#                                                                  max_pooling2d_16[13][0]
#                                                                  max_pooling2d_16[14][0]
#                                                                  max_pooling2d_16[15][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_22[0][0]
#                                                                  conv2d_22[1][0]
#                                                                  conv2d_22[2][0]
#                                                                  conv2d_22[3][0]
#                                                                  conv2d_22[4][0]
#                                                                  conv2d_22[5][0]
#                                                                  conv2d_22[6][0]
#                                                                  conv2d_22[7][0]
#                                                                  conv2d_22[8][0]
#                                                                  conv2d_22[9][0]
#                                                                  conv2d_22[10][0]
#                                                                  conv2d_22[11][0]
#                                                                  conv2d_22[12][0]
#                                                                  conv2d_22[13][0]
#                                                                  conv2d_22[14][0]
#                                                                  conv2d_22[15][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 128)    73856       max_pooling2d_17[0][0]
#                                                                  max_pooling2d_17[1][0]
#                                                                  max_pooling2d_17[2][0]
#                                                                  max_pooling2d_17[3][0]
#                                                                  max_pooling2d_17[4][0]
#                                                                  max_pooling2d_17[5][0]
#                                                                  max_pooling2d_17[6][0]
#                                                                  max_pooling2d_17[7][0]
#                                                                  max_pooling2d_17[8][0]
#                                                                  max_pooling2d_17[9][0]
#                                                                  max_pooling2d_17[10][0]
#                                                                  max_pooling2d_17[11][0]
#                                                                  max_pooling2d_17[12][0]
#                                                                  max_pooling2d_17[13][0]
#                                                                  max_pooling2d_17[14][0]
#                                                                  max_pooling2d_17[15][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 128)    147584      conv2d_23[0][0]
#                                                                  conv2d_23[1][0]
#                                                                  conv2d_23[2][0]
#                                                                  conv2d_23[3][0]
#                                                                  conv2d_23[4][0]
#                                                                  conv2d_23[5][0]
#                                                                  conv2d_23[6][0]
#                                                                  conv2d_23[7][0]
#                                                                  conv2d_23[8][0]
#                                                                  conv2d_23[9][0]
#                                                                  conv2d_23[10][0]
#                                                                  conv2d_23[11][0]
#                                                                  conv2d_23[12][0]
#                                                                  conv2d_23[13][0]
#                                                                  conv2d_23[14][0]
#                                                                  conv2d_23[15][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 2, 2, 128)    0           conv2d_24[0][0]
#                                                                  conv2d_24[1][0]
#                                                                  conv2d_24[2][0]
#                                                                  conv2d_24[3][0]
#                                                                  conv2d_24[4][0]
#                                                                  conv2d_24[5][0]
#                                                                  conv2d_24[6][0]
#                                                                  conv2d_24[7][0]
#                                                                  conv2d_24[8][0]
#                                                                  conv2d_24[9][0]
#                                                                  conv2d_24[10][0]
#                                                                  conv2d_24[11][0]
#                                                                  conv2d_24[12][0]
#                                                                  conv2d_24[13][0]
#                                                                  conv2d_24[14][0]
#                                                                  conv2d_24[15][0]
# __________________________________________________________________________________________________
# flatten_81 (Flatten)            (None, 512)          0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# flatten_82 (Flatten)            (None, 512)          0           max_pooling2d_18[1][0]
# __________________________________________________________________________________________________
# flatten_83 (Flatten)            (None, 512)          0           max_pooling2d_18[2][0]
# __________________________________________________________________________________________________
# flatten_84 (Flatten)            (None, 512)          0           max_pooling2d_18[3][0]
# __________________________________________________________________________________________________
# flatten_85 (Flatten)            (None, 512)          0           max_pooling2d_18[4][0]
# __________________________________________________________________________________________________
# flatten_86 (Flatten)            (None, 512)          0           max_pooling2d_18[5][0]
# __________________________________________________________________________________________________
# flatten_87 (Flatten)            (None, 512)          0           max_pooling2d_18[6][0]
# __________________________________________________________________________________________________
# flatten_88 (Flatten)            (None, 512)          0           max_pooling2d_18[7][0]
# __________________________________________________________________________________________________
# flatten_89 (Flatten)            (None, 512)          0           max_pooling2d_18[8][0]
# __________________________________________________________________________________________________
# flatten_90 (Flatten)            (None, 512)          0           max_pooling2d_18[9][0]
# __________________________________________________________________________________________________
# flatten_91 (Flatten)            (None, 512)          0           max_pooling2d_18[10][0]
# __________________________________________________________________________________________________
# flatten_92 (Flatten)            (None, 512)          0           max_pooling2d_18[11][0]
# __________________________________________________________________________________________________
# flatten_93 (Flatten)            (None, 512)          0           max_pooling2d_18[12][0]
# __________________________________________________________________________________________________
# flatten_94 (Flatten)            (None, 512)          0           max_pooling2d_18[13][0]
# __________________________________________________________________________________________________
# flatten_95 (Flatten)            (None, 512)          0           max_pooling2d_18[14][0]
# __________________________________________________________________________________________________
# flatten_96 (Flatten)            (None, 512)          0           max_pooling2d_18[15][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8192)         0           flatten_81[0][0]
#                                                                  flatten_82[0][0]
#                                                                  flatten_83[0][0]
#                                                                  flatten_84[0][0]
#                                                                  flatten_85[0][0]
#                                                                  flatten_86[0][0]
#                                                                  flatten_87[0][0]
#                                                                  flatten_88[0][0]
#                                                                  flatten_89[0][0]
#                                                                  flatten_90[0][0]
#                                                                  flatten_91[0][0]
#                                                                  flatten_92[0][0]
#                                                                  flatten_93[0][0]
#                                                                  flatten_94[0][0]
#                                                                  flatten_95[0][0]
#                                                                  flatten_96[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 8192)         0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 2048)         16779264    dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 2048)         0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 2048)         4196352     dropout_17[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 2048)         0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 37)           75813       dropout_18[0][0]
# ==================================================================================================
# Total params: 21,327,621
# Trainable params: 21,327,621
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_set = np.empty((61578, 69, 69, 3), dtype='int16')
i = 0
for imagename in tqdm(glob.glob(path+'train/*.png')):
    train_set[i] = imageio.imread(imagename)
    i += 1
# Out:
# 100%|██████████| 61578/61578 [19:01<00:00, 53.94it/s]

# %%
solutions = pd.read_csv(path+'training_solutions_rev1.csv', index_col='GalaxyID')
solutions.head()
# Out:
#           Class1.1  Class1.2  Class1.3  ...  Class11.4  Class11.5  Class11.6
# GalaxyID                                ...
# 100008    0.383147  0.616853  0.000000  ...        0.0        0.0   0.325512
# 100023    0.327001  0.663777  0.009222  ...        0.0        0.0   0.000000
# 100053    0.765717  0.177352  0.056931  ...        0.0        0.0   0.000000
# 100078    0.693377  0.238564  0.068059  ...        0.0        0.0   0.000000
# 100090    0.933839  0.000000  0.066161  ...        0.0        0.0   0.000000
#
# [5 rows x 37 columns]

# %%
X_train = train_set[:50000]
X_valid = train_set[50000:]
y_train = solutions.iloc[:50000, :]
y_valid = solutions.iloc[50000:, :]

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint('best_weights.h5', save_best_only=True, save_weights_only=True),  # save best model
    keras.callbacks.EarlyStopping(patience=20, verbose=1)  # early stop
]

big_model.fit(X_train, y_train, batch_size=100, epochs=100, 
              callbacks=callbacks, shuffle=True, 
              validation_data=(X_valid, y_valid))
# Out:
# WARNING:tensorflow:From /home/sakar/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 11578 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1291s 26ms/step - loss: 0.2085 - val_loss: 0.0737
# Epoch 2/100
# 40100/50000 [=======================>......] - ETA: 3:59 - loss: 0.0738
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-7f77e8f9757f> in <module>
#       4 ]
#       5
# ----> 6 big_model.fit(X_train, y_train, batch_size=100, epochs=100, callbacks=callbacks, shuffle=True, validation_data=(X_valid, y_valid))
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
del train_set
del X_train
del X_valid

test_set = np.empty((79975, 69, 69, 3), dtype='int16')
i = 0
for imagename in tqdm(glob.glob(path+'test/*.png')):
    test_set[i] = imageio.imread(imagename)
    i += 1

# %%
submission = model.predict(test_set)

# %%
tmp = pd.DataFrame(submission)
tmp.head()

# %%
tmp.describe()
